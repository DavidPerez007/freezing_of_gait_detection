# %% [markdown]
# # Install Missing Dependencies
#
# Run this notebook once to install all required packages in the current Jupyter kernel.

# %%
# Install packages in the current kernel
import sys
# !{sys.executable} -m pip install PyWavelets imbalanced-learn joblib tqdm
# Out:
# ...
#   Using cached imbalanced_learn-0.14.1-py3-none-any.whl.metadata (8.9 kB)
# ...
#   Using cached sklearn_compat-0.1.5-py3-none-any.whl.metadata (20 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 7.8 MB/s  0:00:00 eta 0:00:01
# Using cached imbalanced_learn-0.14.1-py3-none-any.whl (235 kB)
# Using cached sklearn_compat-0.1.5-py3-none-any.whl (20 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [imbalanced-learn][imbalanced-learn]
# ...

# %%
# Verify installation
import pywt
import imblearn
import joblib
import tqdm

print("✅ All packages installed successfully!")
print(f"PyWavelets version: {pywt.__version__}")
print(f"imbalanced-learn version: {imblearn.__version__}")
print(f"joblib version: {joblib.__version__}")
# Out:
# ✅ All packages installed successfully!
# PyWavelets version: 1.8.0
# imbalanced-learn version: 0.14.1
# joblib version: 1.5.3
